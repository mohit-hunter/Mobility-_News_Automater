# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_json("master_news_archive.json")

# %%
df.head
# Out:
# <bound method NDFrame.head of           Date                                 Executive Headline  \
# 0   2025-11-25  Elon Musk admits other automakers don’t want t...
# 1   2025-11-24  CPSC warns Rad Power Bikes owners to stop usin...
# 2   2025-11-24  Rivian’s e-bike brand launches $250 smart helm...
# 3   2025-11-24  Georgia gets 26 new DC fast-charging stations ...
# 4   2025-11-24  Tesla Pushes Mysterious 'Unsupervised' Geofenc...
# ..         ...                                                ...
# 648 2026-01-23  Lectric eBikes just did something it almost ne...
# 649 2026-01-23  The Volkswagen ID.4 gets a sharp redesign and ...
# 650 2026-01-23  Solar car maker Aptera (SEV) prices $9 million...
# 651 2026-01-23  Tesla cuts standard Autopilot, paywalls basic ...
# 652 2026-01-23  Heybike Villain launched as low-cost 45 MPH li...
#
#                                                Summary  \
# 0    After years of teasing that other automakers w...
# ...

# %%
df.to_csv("news.csv", index=False)

# %%
df.info()
print(df.head())
print(df.tail())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 858 non-null    datetime64[us]
#  1   Executive Headline   858 non-null    str
#  2   Summary              858 non-null    str
#  3   Source URL           858 non-null    str
#  4   Source               858 non-null    str
#  5   Cluster ID           858 non-null    int64
#  6   execution_timestamp  858 non-null    str
# dtypes: datetime64[us](1), int64(1), str(5)
# memory usage: 47.1 KB
#         Date                                 Executive Headline  \
# 0 2025-11-25  Elon Musk admits other automakers don’t want t...
# 1 2025-11-24  CPSC warns Rad Power Bikes owners to stop usin...
# 2 2025-11-24  Rivian’s e-bike brand launches $250 smart helm...
# 3 2025-11-24  Georgia gets 26 new DC fast-charging stations ...
# ...
